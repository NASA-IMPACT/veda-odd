# %%
import boto3
import s3fs
import xarray as xr

import helpers
from create_stac_item import create_stac_item

# %%
bucket = 'nasa-eodc-scratch'
directory = 'NLDAS/netcdf/.timechunk24'
file = 'NLDAS_FOR0010_H.A20010101.030.beta.nc'

# %%
credentials = helpers.get_credentials()

# %%
s3fsfs = helpers.create_s3filesystem(credentials)
s3fsfs

# %%
# %%time
ds = xr.open_dataset(s3fsfs.open(f's3://{bucket}/{directory}/{file}'), chunks={})
# Out:
# CPU times: user 5.57 s, sys: 2.37 s, total: 7.94 s
# Wall time: 35.1 s

# %%
create_stac_item(ds, f's3://{bucket}/{directory}/{file}')
# Out:
# <Item id=nldas-20250508-212517>
